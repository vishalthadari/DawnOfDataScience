# %%
import pandas as pd
import numpy as np

# %%
cars1 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv")
cars2 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv")

print(cars1.head())
print(cars2.head())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %%
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# ...

# %% [markdown]
# delete those columns which have missing values i.e. columns after car

# %%
cars1 = cars1.loc[:, "mpg":"car"]
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
print(cars1.shape)
print(cars2.shape)
# Out:
# (198, 9)
# (200, 9)

# %% [markdown]
# Lets join cars1 and cars2 into a single data frame

# %%
cars = cars1.append(cars2)
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# 5    15.0          8           429        198    4341          10.0     70
# 6    14.0          8           454        220    4354           9.0     70
# 7    14.0          8           440        215    4312           8.5     70
# 8    14.0          8           455        225    4425          10.0     70
# 9    15.0          8           390        190    3850           8.5     70
# 10   15.0          8           383        170    3563          10.0     70
# ...

# %% [markdown]
# lets add a random column to the data and attach random data to it

# %%
nr_owners = np.random.randint(15000, high=73001, size=398, dtype='l')
nr_owners
# Out:
# array([58582, 40932, 20467, 49407, 32256, 61411, 44958, 43676, 56482,
#        63464, 57546, 59926, 36791, 55733, 35345, 55863, 72008, 15567,
#        44174, 54774, 69526, 16483, 66546, 51522, 49646, 60137, 23326,
#        26661, 58707, 49799, 53552, 69396, 54566, 21891, 55030, 41143,
#        43493, 66745, 29270, 56367, 43716, 44428, 70192, 49097, 25697,
#        62931, 43669, 72606, 53377, 15724, 71546, 36843, 54142, 40666,
#        28072, 39229, 48849, 70431, 71827, 24276, 72063, 61882, 43463,
#        35709, 33964, 24452, 30821, 46061, 54010, 35357, 57380, 20955,
#        38329, 17517, 26110, 58594, 41779, 20808, 57795, 72448, 53084,
#        29574, 41949, 21218, 42161, 43634, 29742, 41734, 32466, 61251,
#        63693, 47445, 67716, 18138, 33251, 15447, 69073, 57452, 17436,
#        68882, 21683, 53064, 41639, 47172, 70329, 30050, 21382, 49887,
#        64627, 19760, 39412, 31496, 44282, 71877, 49242, 21708, 39215,
# ...

# %%
cars['owners'] = nr_owners
cars.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin              car  owners
# 195       1  ford mustang gl   35791
# 196       2        vw pickup   50585
# 197       1    dodge rampage   33767
# 198       1      ford ranger   63973
# 199       1       chevy s-10   61826

# %% [markdown]
# Lets Create a data with raw data

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %% [markdown]
# Assign each to a variable called data1, data2, data3

# %%
data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

data2
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
# Join the two dataframes along rows and assign all_data¶

# %%
all_data = pd.concat([data1, data2])
all_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
# Join the two dataframes along columns and assing to all_data_col

# %%
all_data_col = pd.concat([data1, data2], axis = 1)
all_data_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %% [markdown]
# Merge all_data and data3 along the subject_id value

# %%
pd.merge(all_data, data3, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %% [markdown]
#  Merge only the data that has the same 'subject_id' on both data1 and data2¶

# %%
pd.merge(data1, data2, on='subject_id', how='inner')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %% [markdown]
# Step 9. Merge all values in data1 and data2, with matching records from both sides where available.

# %%
pd.merge(data1, data2, on='subject_id', how='outer')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  owners
# 0       1  chevrolet chevelle malibu   58582
# 1       1          buick skylark 320   40932
# 2       1         plymouth satellite   20467
# 3       1              amc rebel sst   49407
# 4       1                ford torino   32256

# %% [markdown]
# Lets modify these columns a little

# %%
cars.columns = ['MPG','Cylinders', 'Displacement', 'HP', 'Weight',"acceleration","model","origin","car","owners"]
cars.head()
# Out:
#     MPG  Cylinders  Displacement   HP  Weight  acceleration  model  origin  \
# 0  18.0          8           307  130    3504          12.0     70       1
# 1  15.0          8           350  165    3693          11.5     70       1
# 2  18.0          8           318  150    3436          11.0     70       1
# 3  16.0          8           304  150    3433          12.0     70       1
# 4  17.0          8           302  140    3449          10.5     70       1
#
#                          car  owners
# 0  chevrolet chevelle malibu   58582
# 1          buick skylark 320   40932
# 2         plymouth satellite   20467
# 3              amc rebel sst   49407
# 4                ford torino   32256

# %% [markdown]
# is there any missing values in the dataset?

# %%
pd.isnull(cars).sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# HP              0
# Weight          0
# acceleration    0
# model           0
# origin          0
# car             0
# owners          0
# dtype: int64

# %% [markdown]
# as we can see that there is no missing values in the dataset so lets create some missing values!

# %%
#Lets set the values of the rows 10 to 29 of the column 'Displacement' to NaN¶

cars.iloc[10:30,2:3] = np.nan
cars.head(20)
# Out:
#      MPG  Cylinders  Displacement   HP  Weight  acceleration  model  origin  \
# 0   18.0          8         307.0  130    3504          12.0     70       1
# 1   15.0          8         350.0  165    3693          11.5     70       1
# 2   18.0          8         318.0  150    3436          11.0     70       1
# 3   16.0          8         304.0  150    3433          12.0     70       1
# 4   17.0          8         302.0  140    3449          10.5     70       1
# 5   15.0          8         429.0  198    4341          10.0     70       1
# 6   14.0          8         454.0  220    4354           9.0     70       1
# 7   14.0          8         440.0  215    4312           8.5     70       1
# 8   14.0          8         455.0  225    4425          10.0     70       1
# 9   15.0          8         390.0  190    3850           8.5     70       1
# 10  15.0          8           NaN  170    3563          10.0     70       1
# ...

# %%
cars.Displacement.fillna(1, inplace = True)
cars
# Out:
#       MPG  Cylinders  Displacement   HP  Weight  acceleration  model  origin  \
# 0    18.0          8         307.0  130    3504          12.0     70       1
# 1    15.0          8         350.0  165    3693          11.5     70       1
# 2    18.0          8         318.0  150    3436          11.0     70       1
# 3    16.0          8         304.0  150    3433          12.0     70       1
# 4    17.0          8         302.0  140    3449          10.5     70       1
# 5    15.0          8         429.0  198    4341          10.0     70       1
# 6    14.0          8         454.0  220    4354           9.0     70       1
# 7    14.0          8         440.0  215    4312           8.5     70       1
# 8    14.0          8         455.0  225    4425          10.0     70       1
# 9    15.0          8         390.0  190    3850           8.5     70       1
# 10   15.0          8           1.0  170    3563          10.0     70       1
# ...

# %% [markdown]
# lets delete the owners

# %%
del cars['owners']
cars.head()
# Out:
#     MPG  Cylinders  Displacement   HP  Weight  acceleration  model  origin  \
# 0  18.0          8         307.0  130    3504          12.0     70       1
# 1  15.0          8         350.0  165    3693          11.5     70       1
# 2  18.0          8         318.0  150    3436          11.0     70       1
# 3  16.0          8         304.0  150    3433          12.0     70       1
# 4  17.0          8         302.0  140    3449          10.5     70       1
#
#                          car
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %% [markdown]
# Set the first 3 rows as NaN

# %%
cars.iloc[0:3 ,:] = np.nan
cars.head()
# Out:
#     MPG  Cylinders  Displacement   HP  Weight  acceleration  model  origin  \
# 0   NaN        NaN           NaN  NaN     NaN           NaN    NaN     NaN
# 1   NaN        NaN           NaN  NaN     NaN           NaN    NaN     NaN
# 2   NaN        NaN           NaN  NaN     NaN           NaN    NaN     NaN
# 3  16.0        8.0         304.0  150  3433.0          12.0   70.0     1.0
# 4  17.0        8.0         302.0  140  3449.0          10.5   70.0     1.0
#
#              car
# 0            NaN
# 1            NaN
# 2            NaN
# 3  amc rebel sst
# 4    ford torino

# %% [markdown]
# Delete the rows that have NaN

# %%
cars = cars.dropna(how='any')
cars.head()
# Out:
#     MPG  Cylinders  Displacement   HP  Weight  acceleration  model  origin  \
# 3  16.0        8.0         304.0  150  3433.0          12.0   70.0     1.0
# 4  17.0        8.0         302.0  140  3449.0          10.5   70.0     1.0
# 5  15.0        8.0         429.0  198  4341.0          10.0   70.0     1.0
# 6  14.0        8.0         454.0  220  4354.0           9.0   70.0     1.0
# 7  14.0        8.0         440.0  215  4312.0           8.5   70.0     1.0
#
#                  car
# 3      amc rebel sst
# 4        ford torino
# 5   ford galaxie 500
# 6   chevrolet impala
# 7  plymouth fury iii

# %% [markdown]
# serial number starting from 3 lets reset it

# %%
cars = cars.reset_index(drop = True)
cars.head()
# Out:
#     MPG  Cylinders  Displacement   HP  Weight  acceleration  model  origin  \
# 0  16.0        8.0         304.0  150  3433.0          12.0   70.0     1.0
# 1  17.0        8.0         302.0  140  3449.0          10.5   70.0     1.0
# 2  15.0        8.0         429.0  198  4341.0          10.0   70.0     1.0
# 3  14.0        8.0         454.0  220  4354.0           9.0   70.0     1.0
# 4  14.0        8.0         440.0  215  4312.0           8.5   70.0     1.0
#
#                  car
# 0      amc rebel sst
# 1        ford torino
# 2   ford galaxie 500
# 3   chevrolet impala
# 4  plymouth fury iii

# %% [markdown]
#  Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
cars = cars.drop(cars.columns[[0,3,6]], axis = 1)

cars.head()
# Out:
#    Cylinders  Displacement  Weight  acceleration  origin                car
# 0        8.0         304.0  3433.0          12.0     1.0      amc rebel sst
# 1        8.0         302.0  3449.0          10.5     1.0        ford torino
# 2        8.0         429.0  4341.0          10.0     1.0   ford galaxie 500
# 3        8.0         454.0  4354.0           9.0     1.0   chevrolet impala
# 4        8.0         440.0  4312.0           8.5     1.0  plymouth fury iii

# %%
cars.head()
# Out:
#    Cylinders  Displacement  Weight  acceleration  origin                car
# 0        8.0         304.0  3433.0          12.0     1.0      amc rebel sst
# 1        8.0         302.0  3449.0          10.5     1.0        ford torino
# 2        8.0         429.0  4341.0          10.0     1.0   ford galaxie 500
# 3        8.0         454.0  4354.0           9.0     1.0   chevrolet impala
# 4        8.0         440.0  4312.0           8.5     1.0  plymouth fury iii
