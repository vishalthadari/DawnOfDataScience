# %%
import pandas as pd

# %%
data = pd.read_csv('/home/vishalthadari/Documents/Train.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# select only Item_Type Column

# %%
data.Item_Type
# Out:
# 0                       Dairy
# 1                 Soft Drinks
# 2                        Meat
# 3       Fruits and Vegetables
# 4                   Household
# 5                Baking Goods
# 6                 Snack Foods
# 7                 Snack Foods
# 8                Frozen Foods
# 9                Frozen Foods
# 10      Fruits and Vegetables
# 11                      Dairy
# 12      Fruits and Vegetables
# 13                Snack Foods
# 14      Fruits and Vegetables
# 15                  Breakfast
# 16         Health and Hygiene
# 17                  Breakfast
# 18                Hard Drinks
# 19                      Dairy
# 20                Snack Foods
# 21               Baking Goods
# 22                  Household
# 23               Baking Goods
# 24               Frozen Foods
# 25                  Household
# 26                Snack Foods
# 27                Hard Drinks
# 28                      Dairy
# 29                     Canned
#                 ...
# ...

# %% [markdown]
# Total Number of Items?

# %%
data.Item_Identifier.shape[0]
# Out:
# 8523

# %% [markdown]
# number of columns in the dataset

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.1+ KB

# %% [markdown]
# View only Item_identifier,Item_MRP,Item_Outlet_Sales

# %%
variable1 = data[['Item_Identifier', 'Item_MRP', 'Item_Outlet_Sales']]
variable1
# Out:
#      Item_Identifier  Item_MRP  Item_Outlet_Sales
# 0              FDA15  249.8092          3735.1380
# 1              DRC01   48.2692           443.4228
# 2              FDN15  141.6180          2097.2700
# 3              FDX07  182.0950           732.3800
# 4              NCD19   53.8614           994.7052
# 5              FDP36   51.4008           556.6088
# 6              FDO10   57.6588           343.5528
# 7              FDP10  107.7622          4022.7636
# 8              FDH17   96.9726          1076.5986
# 9              FDU28  187.8214          4710.5350
# 10             FDY07   45.5402          1516.0266
# 11             FDA03  144.1102          2187.1530
# 12             FDX32  145.4786          1589.2646
# 13             FDS46  119.6782          2145.2076
# 14             FDF32  196.4426          1977.4260
# 15             FDP49   56.3614          1547.3192
# 16             NCB42  115.3492          1621.8888
# 17             FDP49   54.3614           718.3982
# ...

# %% [markdown]
# Sort the values by Item_MRP then to Item_Outlet_Sales

# %%
variable1.sort_values(['Item_MRP', 'Item_Outlet_Sales'], ascending = False)
# Out:
#      Item_Identifier  Item_MRP  Item_Outlet_Sales
# 5884           FDR25  266.8884          5034.7796
# 4802           FDS13  266.8884          1059.9536
# 5254           NCS29  266.6884          3974.8260
# 4159           FDK51  266.6884           264.9884
# 5558           NCS29  266.5884          6624.7100
# 4538           FDS13  266.5884          1324.9420
# 4877           NCS29  266.2884          2914.8724
# 3714           FDS13  266.1884          5299.7680
# 3416           FDK51  266.1884          3179.8608
# 8375           NCM05  266.0226           528.6452
# 4195           FDK51  265.8884          2649.8840
# 3248           FDR25  265.7884          3974.8260
# 3814           FDR25  265.6884          2649.8840
# 7085           FDU12  265.5568          4482.1656
# 5859           FDK51  265.2884          3179.8608
# 6670           FDS13  265.2884           264.9884
# 7951           FDB15  265.2568          4218.5088
# 47             FDV49  265.2226          5815.0972
# ...

# %% [markdown]
# Calculate the mean of Item_Outlet_Sales

# %%
round(variable1['Item_Outlet_Sales'].mean())
# Out:
# 2181.0

# %% [markdown]
# Filter the Product that have more than $260 MRP

# %%
variable1[variable1.Item_MRP > 260]
# Out:
#      Item_Identifier  Item_MRP  Item_Outlet_Sales
# 47             FDV49  265.2226          5815.0972
# 191            FDL58  264.7568          4745.8224
# 212            FDL58  263.7568          2636.5680
# 217            FDP28  260.0936           260.9936
# 249            FDF05  262.4910          5259.8200
# 271            FDS26  260.1594          2093.2752
# 273            FDK51  264.0884          5829.7448
# 332            FDU55  260.6278          4425.5726
# 351            FDR59  260.4594          5494.8474
# 444            FDJ41  261.6594          3401.5722
# 456            FDS26  260.5594          9158.0790
# 502            FDB15  263.4568           527.3136
# 566            FDL58  264.9568          1845.5976
# 741            FDY02  264.7910          4733.8380
# 868            NCB31  261.9910          2366.9190
# 895            FDB15  263.0568           527.3136
# 1013           FDR59  260.4594          3139.9128
# 1019           FDP28  261.2936          3131.9232
# ...

# %%
 Select the Item_Identifier that start with FDO

# %%
variable1[variable1.Item_Identifier.str.startswith('FDO')]
# Out:
#      Item_Identifier  Item_MRP  Item_Outlet_Sales
# 6              FDO10   57.6588           343.5528
# 33             FDO23   93.1436          2174.5028
# 179            FDO24  157.4604          3010.7476
# 186            FDO08  165.7526           657.8104
# 303            FDO23   93.7436          1134.5232
# 335            FDO01  129.3994          2055.9904
# 374            FDO51   41.2112           809.6128
# 465            FDO28  119.9098          2048.6666
# 491            FDO11  248.8092          3486.1288
# 537            FDO19   47.4034          2187.1530
# 538            FDO04   57.2614          1049.9666
# 570            FDO22   81.5960           639.1680
# 588            FDO44  109.2228          3205.1612
# 619            FDO19   48.1034           534.6374
# 669            FDO51   43.4112          1107.8912
# 671            FDO27   95.2752          1534.0032
# 723            FDO52  172.1106          2566.6590
# 738            FDO34  165.9816          4362.3216
# ...

# %% [markdown]
# How to Select The First Seven Columns?

# %%
data.iloc[: , 0:7]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %% [markdown]
# Select All Columns Except Last three

# %%
data.iloc[: , :-3]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
thadari=data.head(50)
thadari.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# Present only three item_identifer i.e.'FDA15', 'DRC01', 'FDN15' from the column 'Item_MRP','Item_Outlet_Sales'

# %%
thadari.loc[thadari.Item_Identifier.isin(['FDA15', 'DRC01', 'FDN15']), ['Item_MRP','Item_Outlet_Sales']]
# Out:
#    Item_MRP  Item_Outlet_Sales
# 0  249.8092          3735.1380
# 1   48.2692           443.4228
# 2  141.6180          2097.2700

# %% [markdown]
# Select only the products with quantity equals to 1

# %%
Variable2 = data[data.Outlet_Establishment_Year == 1999]

# %%
Variable2.head()
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15          9.3          Low Fat         0.016047
# 2            FDN15         17.5          Low Fat         0.016760
# 10           FDY07         11.8          Low Fat         0.000000
# 12           FDX32         15.1          Regular         0.100014
# 17           FDP49          9.0          Regular         0.069196
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0                   Dairy  249.8092            OUT049
# 2                    Meat  141.6180            OUT049
# 10  Fruits and Vegetables   45.5402            OUT049
# 12  Fruits and Vegetables  145.4786            OUT049
# 17              Breakfast   54.3614            OUT049
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                        1999      Medium               Tier 1
# 2                        1999      Medium               Tier 1
# ...

# %% [markdown]
# Sort the MRP from the most to less expensive

# %%
data.sort_values(by = "Item_MRP", ascending = False).head(20)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4802           FDS13        6.465          Low Fat         0.125210
# 5884           FDR25       17.000          Regular         0.139522
# 4159           FDK51       19.850          Low Fat         0.008763
# 5254           NCS29        9.000          Low Fat         0.069488
# 4538           FDS13          NaN          Low Fat         0.217994
# 5558           NCS29        9.000          Low Fat         0.069532
# 4877           NCS29        9.000          Low Fat         0.069654
# 3714           FDS13        6.465          Low Fat         0.124403
# 3416           FDK51       19.850          Low Fat         0.005243
# 8375           NCM05          NaN          Low Fat         0.104784
# 4195           FDK51       19.850          Low Fat         0.005235
# 3248           FDR25       17.000          Regular         0.139805
# 3814           FDR25       17.000          Regular         0.140311
# ...

# %% [markdown]
# What is the weight of the most expensive item ordered?

# %%
data.sort_values(by = "Item_MRP", ascending = False).head(1)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 4802           FDS13        6.465          Low Fat          0.12521    Canned
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 4802  266.8884            OUT017                       2007         NaN
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 4802               Tier 2  Supermarket Type1          1059.9536

# %% [markdown]
# How many 'FDS13' items are in Item_Identfier?

# %%
variable3 = data[data.Item_Identifier == "FDS13"]

len(variable3)
# Out:
# 7

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# Exercise on Iloc

# %% [markdown]
# Select the rows 3 to 7 and the columns 3 to 6¶

# %%
data.iloc[3:7, 3:6]
# Out:
#    Item_Visibility              Item_Type  Item_MRP
# 3         0.000000  Fruits and Vegetables  182.0950
# 4         0.000000              Household   53.8614
# 5         0.000000           Baking Goods   51.4008
# 6         0.012741            Snack Foods   57.6588

# %% [markdown]
# Select every row after the fourth row

# %%
data.iloc[3:]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# 13             FDS46       17.600          Regular         0.047257
# 14             FDF32       16.350          Low Fat         0.068024
# 15             FDP49        9.000          Regular         0.069089
# ...

# %% [markdown]
# Select every row up to the 4th row¶

# %%
data.iloc[:3]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
# 2           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700

# %% [markdown]
#  Select the 3rd column up to the 7th column

# %%
data.iloc[: , 4:7]
# Out:
#                   Item_Type  Item_MRP Outlet_Identifier
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# 5              Baking Goods   51.4008            OUT018
# 6               Snack Foods   57.6588            OUT013
# 7               Snack Foods  107.7622            OUT027
# 8              Frozen Foods   96.9726            OUT045
# 9              Frozen Foods  187.8214            OUT017
# 10    Fruits and Vegetables   45.5402            OUT049
# 11                    Dairy  144.1102            OUT046
# 12    Fruits and Vegetables  145.4786            OUT049
# 13              Snack Foods  119.6782            OUT046
# 14    Fruits and Vegetables  196.4426            OUT013
# 15                Breakfast   56.3614            OUT046
# ...

# %% [markdown]
#  Select rows where df.Item_MRP is greater than 260

# %%
data[data['Item_MRP'] > 260]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 47             FDV49       10.000          Low Fat         0.025880
# 191            FDL58        5.780          Regular         0.074264
# 212            FDL58        5.780          Regular         0.000000
# 217            FDP28       13.650          Regular         0.134976
# 249            FDF05       17.500          Low Fat         0.027023
# 271            FDS26       20.350          Low Fat         0.089395
# 273            FDK51       19.850          Low Fat         0.005234
# 332            FDU55       16.200          Low Fat         0.035984
# 351            FDR59       14.500          Regular         0.063993
# 444            FDJ41        6.850          Low Fat         0.022976
# 456            FDS26          NaN          Low Fat         0.089036
# 502            FDB15       10.895          Low Fat         0.228993
# 566            FDL58        5.780          Regular         0.074299
# ...

# %% [markdown]
# Select rows where df.Item_MRP is greater than 500 or less than 600

# %%
data[(data['Item_MRP'] > 500) | (data['Item_MRP'] < 600)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %% [markdown]
# Select all the Item_fat_Content not named "Regular"

# %%
data[(data['Item_Fat_Content'] != 'Regular')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 4              NCD19        8.930          Low Fat         0.000000
# 7              FDP10          NaN          Low Fat         0.127470
# 10             FDY07       11.800          Low Fat         0.000000
# 14             FDF32       16.350          Low Fat         0.068024
# 16             NCB42       11.800          Low Fat         0.008596
# 18             DRI11          NaN          Low Fat         0.034238
# 19             FDU02       13.350          Low Fat         0.102492
# 22             NCB30       14.600          Low Fat         0.025698
# 23             FDC37          NaN          Low Fat         0.057557
# 25             NCD06       13.000          Low Fat         0.099887
# 27             DRJ59       11.650          low fat         0.019356
# ...

# %% [markdown]
# assign Item_Identifier as Header

# %%
data.set_index(data.columns[0], inplace = True)

# %%
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
data.loc[['FDA15', 'NCD19']]
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  Item_Type  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047      Dairy
# FDA15                   9.30          Low Fat         0.016055      Dairy
# FDA15                   9.30          Low Fat         0.016019      Dairy
# FDA15                   9.30          Low Fat         0.016088      Dairy
# FDA15                   9.30          Low Fat         0.026818      Dairy
# FDA15                   9.30          Low Fat         0.016009      Dairy
# FDA15                    NaN          Low Fat         0.015945      Dairy
# FDA15                   9.30               LF         0.016113      Dairy
# NCD19                   8.93          Low Fat         0.000000  Household
# NCD19                   8.93          Low Fat         0.022060  Household
# NCD19                   8.93          Low Fat         0.000000  Household
# ...

# %% [markdown]
# Select the third cell down in the column named Item_Weight

# %%
data.iloc[[2], data.columns.get_loc('Item_Weight')]
# Out:
# Item_Identifier
# FDN15    17.5
# Name: Item_Weight, dtype: float64

# %%
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...
