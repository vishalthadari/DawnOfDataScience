# %%
import pandas as pd
import numpy

# %%
data = pd.read_csv('/home/vishalthadari/Documents/Train.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# show the columns from STA to snowfall

# %%
variable1 = data.loc[: , "Item_Identifier":"Outlet_Identifier"]
variable1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013

# %% [markdown]
# create a lambda function that capitalize strings

# %%
captalizer = lambda x: x.upper()

# %% [markdown]
# for visuals only on data

# %%
variable1['Item_Fat_Content'].apply(captalizer)
variable1['Item_Type'].apply(captalizer)
# Out:
# 0                       DAIRY
# 1                 SOFT DRINKS
# 2                        MEAT
# 3       FRUITS AND VEGETABLES
# 4                   HOUSEHOLD
# 5                BAKING GOODS
# 6                 SNACK FOODS
# 7                 SNACK FOODS
# 8                FROZEN FOODS
# 9                FROZEN FOODS
# 10      FRUITS AND VEGETABLES
# 11                      DAIRY
# 12      FRUITS AND VEGETABLES
# 13                SNACK FOODS
# 14      FRUITS AND VEGETABLES
# 15                  BREAKFAST
# 16         HEALTH AND HYGIENE
# 17                  BREAKFAST
# 18                HARD DRINKS
# 19                      DAIRY
# 20                SNACK FOODS
# 21               BAKING GOODS
# 22                  HOUSEHOLD
# 23               BAKING GOODS
# 24               FROZEN FOODS
# 25                  HOUSEHOLD
# 26                SNACK FOODS
# 27                HARD DRINKS
# 28                      DAIRY
# 29                     CANNED
#                 ...
# ...

# %% [markdown]
# apply permanantly capitaliser on the dataset

# %%
variable1['Item_Fat_Content']=variable1['Item_Fat_Content'].apply(captalizer)
variable1['Item_Type']=variable1['Item_Type'].apply(captalizer)
variable1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          LOW FAT         0.016047
# 1           DRC01         5.92          REGULAR         0.019278
# 2           FDN15        17.50          LOW FAT         0.016760
# 3           FDX07        19.20          REGULAR         0.000000
# 4           NCD19         8.93          LOW FAT         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier
# 0                  DAIRY  249.8092            OUT049
# 1            SOFT DRINKS   48.2692            OUT018
# 2                   MEAT  141.6180            OUT049
# 3  FRUITS AND VEGETABLES  182.0950            OUT010
# 4              HOUSEHOLD   53.8614            OUT013

# %%
variable1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013

# %% [markdown]
# last 5 elemennts of the dataset

# %%
variable1.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046

# %% [markdown]
# make a new column new shop and return true if the shop is openened after 2007

# %% [markdown]
# First make a function of it!

# %%
def function1(x):
    if x > 2007:
        return True
    else:
        return False

# %%
data['New Shop'] = data['Outlet_Establishment_Year'].apply(function1)
data.head(20)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 3            FDX07       19.200          Regular         0.000000
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 7            FDP10          NaN          Low Fat         0.127470
# 8            FDH17       16.200          Regular         0.016687
# 9            FDU28       19.200          Regular         0.094450
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# ...

# %% [markdown]
# multiply every number(if the number is int) with 2

# %%
def times10(x):
    if type(x) is int:
        return 2 * x
    return x

# %%
data.applymap(times10).head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %% [markdown]
# we are not doing it on our original data if want to apply on the original data use ",inplace = True" without quotes

# %% [markdown]
# check the information available about the columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# New Shop                     8523 non-null bool
# dtypes: bool(1), float64(4), int64(1), object(7)
# memory usage: 807.4+ KB

# %% [markdown]
# as we can see the Outlet_Establishment_Year is int so we have to apply datetime64(pandas datatype)

# %%
data.Outlet_Establishment_Year = pd.to_datetime(data.Outlet_Establishment_Year, format='%Y')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null datetime64[ns]
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# New Shop                     8523 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(4), object(7)
# memory usage: 807.4+ KB

# %%
data.idxmax(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-76f717b0a50a> in <module>()
# ----> 1 data.idxmax(0)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in idxmax(self, axis, skipna)
#    7040         """
#    7041         axis = self._get_axis_number(axis)
# -> 7042         indices = nanops.nanargmax(self.values, axis=axis, skipna=skipna)
#    7043         index = self._get_axis(axis)
#    7044         result = [index[i] if i >= 0 else np.nan for i in indices]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      72             if any(self.check(obj) for obj in obj_iter):
#      73                 msg = 'reduction operation {name!r} not allowed for this dtype'
# ---> 74                 raise TypeError(msg.format(name=f.__name__.replace('nan', '')))
#      75             try:
# ...
